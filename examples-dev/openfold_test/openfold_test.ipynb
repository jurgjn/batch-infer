# %%
cd ~/batch-infer
./batch-infer singularity_pull results/openfold_test | sbatch
#./batch-infer openfold_test results/openfold_test | sbatch
# Out:
# Submitted batch job 38232453

# %%
my_squeue | grep singularity_pull
# Out:
# 38231936  normal.120h  batch-infer:singularity_pull=results-openfold_test            RUNNING     0:01  7-00:00:00  eu-g9-046-2
