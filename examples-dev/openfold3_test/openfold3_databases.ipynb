# %%
# https://openfold-3.readthedocs.io/en/latest/precomputed_msa_generation_how_to.html
# !mkdir -p $PROJECT/26.02_of3_databases
# !singularity exec --nv --writable-tmpfs \
  --env OPENFOLD_CACHE=/root/.openfold3/ \
  --env TRITON_CACHE_DIR=$TMPDIR/_triton_cache_dir \
  --bind $TMPDIR/_triton_cache_dir \
  --bind $PROJECT/26.02_of3_databases:/root/of3_databases \
  /cluster/project/beltrao/shared/alphafold3/images/openfold3_8a4ff25-setup_openfold.sif \
  sh -c 'python /opt/openfold3/scripts/snakemake_msa/download_of3_databases.py download --output-dir /root/of3_databases'
# Out:
# 2026-02-23 14:26:27,134 - INFO - Jackhmmer databases to process: ['uniprot', 'uniref90', 'mgnify', 'pdb_seqres']
# 2026-02-23 14:26:27,134 - INFO - Downloading uniprot...
# 2026-02-23 14:26:27,134 - INFO - Downloading s3://openfold/alignment_databases/uniprot.fasta.gz to /root/of3_databases/uniprot/uniprot.fasta.gz
# download: s3://openfold/alignment_databases/uniprot.fasta.gz to ../../../../../../../root/of3_databases/uniprot/uniprot.fasta.gz
# 2026-02-23 14:33:29,767 - INFO - Unzipping uniprot...
# 2026-02-23 14:52:16,777 - INFO - Downloading uniref90...
# 2026-02-23 14:52:16,777 - INFO - Downloading s3://openfold/alignment_databases/uniref90.fasta.gz to /root/of3_databases/uniref90/uniref90.fasta.gz
# download: s3://openfold/alignment_databases/uniref90.fasta.gz to ../../../../../../../root/of3_databases/uniref90/uniref90.fasta.gz
# 2026-02-23 15:01:15,072 - INFO - Unzipping uniref90...
# 2026-02-23 15:15:16,785 - INFO - Downloading mgnify...
# ...

# %%
# !du -hs $PROJECT/26.02_of3_databases
# Out:
# 656G	/cluster/project/beltrao/jjaenes/26.02_of3_databases
