# %%
squeue --format="%.18i %.12P %.40j %.8T %.16M %.16l %40R" | column -t --table-right 1,5,6
# Out:
#    JOBID  PARTITION    NAME                                      STATE       TIME  TIME_LIMIT  NODELIST(REASON)
# 11559672  gpuhe.120h   colabfold_predictions:batch_id=67         PENDING     0:00  3-00:00:00  (Priority)
# 11559671  gpuhe.120h   colabfold_predictions:batch_id=65         PENDING     0:00  3-00:00:00  (Priority)
# 11559669  gpuhe.120h   colabfold_predictions:batch_id=72         PENDING     0:00  3-00:00:00  (Priority)
# 11559668  gpuhe.120h   colabfold_predictions:batch_id=158        PENDING     0:00  3-00:00:00  (Priority)
# 11559913  gpuhe.120h   colabfold_predictions:batch_id=77         PENDING     0:00  3-00:00:00  (Priority)
# 11559911  gpuhe.120h   colabfold_predictions:batch_id=57         PENDING     0:00  3-00:00:00  (Priority)
# 11559909  gpuhe.120h   colabfold_predictions:batch_id=7          PENDING     0:00  3-00:00:00  (Priority)
# 11559907  gpuhe.120h   colabfold_predictions:batch_id=2          PENDING     0:00  3-00:00:00  (Priority)
# ...

# %%
squeue --format="%.18i %.12P %.80j %.8T %.16M %.16l %40R" --noheader | grep colabfold_predictions | awk '{print $4}' | sort | uniq -c
# Out:
#     139 PENDING
#      61 RUNNING
