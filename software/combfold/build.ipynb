# %%
time docker buildx build --platform=linux/amd64 --progress plain -t jurgjn/combfold -f Dockerfile .
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 663B done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/python:3.13-slim
# #2 DONE 0.0s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [1/7] FROM docker.io/library/python:3.13-slim@sha256:0e363ca31b820b23242a62c1e702ada9b57bfae2b9905f81b5ed383c54b729f3
# #4 resolve docker.io/library/python:3.13-slim@sha256:0e363ca31b820b23242a62c1e702ada9b57bfae2b9905f81b5ed383c54b729f3 done
# #4 CACHED
#
# #5 [2/7] RUN DEBIAN_FRONTEND=noninteractive apt-get update --quiet     && apt-get install --yes --quiet build-essential git libboost-all-dev     && rm -rf /var/lib/apt/lists/*
# #5 0.303 Hit:1 http://deb.debian.org/debian trixie InRelease
# #5 0.304 Get:2 http://deb.debian.org/debian trixie-updates InRelease [47.3 kB]
# ...

# %%
docker run jurgjn/combfold
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# usage: <script> subunits_info pdbs_folder output_path <optional: crosslinks.txt>

# %%
docker push jurgjn/combfold
# Out:
# Using default tag: latest
# The push refers to repository [docker.io/jurgjn/combfold]
#
# 2b5635e7: Waiting
# ccdcca95: Waiting
# b2dcdf5c: Waiting
# 75b6ee67: Waiting
# 16d26729: Waiting
# efe7e34b: Waiting
# 0a85d03d: Waiting
# 2b59f78d: Waiting
# 1c50db08: Waiting
# e7c1dad5: Waiting
# latest: digest: sha256:6071077a86a8e03c24f83955ba068e5c0dacfe6a3a11d917f44222d49b7f68f9 size: 856
