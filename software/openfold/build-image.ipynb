# %%
git clone https://github.com/aqlaboratory/openfold.git
cd openfold
OPENFOLD_VERSION='v2.2.0'
git checkout $OPENFOLD
cd -
# Out:
# Cloning into 'openfold'...
# remote: Enumerating objects: 8011, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 8011 (delta 71), reused 54 (delta 54), pack-reused 7913 (from 2)
# Receiving objects: 100% (8011/8011), 19.51 MiB | 28.30 MiB/s, done.
# Resolving deltas: 100% (5637/5637), done.
# Your branch is up to date with 'origin/main'.
# /Users/jjaenes/25.06_batch-infer/software/opennfold

# %%
cd openfold
time docker buildx build --platform=linux/amd64 --progress plain -t jurgjn/openfold:$OPENFOLD_VERSION -f Dockerfile .
cd -
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 1.85kB done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/nvidia/cuda:12.1.1-cudnn8-devel-ubuntu22.04
# #2 DONE 3.0s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [internal] load build context
# #4 transferring context: 1.18MB 0.0s done
# #4 DONE 0.0s
#
# #5 [ 1/18] FROM docker.io/nvidia/cuda:12.1.1-cudnn8-devel-ubuntu22.04@sha256:21196d81f56b48dbee70494d5f10322e1a77cc47ffe202a3bf68eab81533c20f
# #5 resolve docker.io/nvidia/cuda:12.1.1-cudnn8-devel-ubuntu22.04@sha256:21196d81f56b48dbee70494d5f10322e1a77cc47ffe202a3bf68eab81533c20f done
# #5 sha256:21196d81f56b48dbee70494d5f10322e1a77cc47ffe202a3bf68eab81533c20f 743B / 743B done
# #5 sha256:aece8493d3972efa43bfd4ee3cdba659c0f787f8f59c82fb3e48c87cbb22a12e 0B / 29.54MB 0.1s
# ...

# %%
docker image ls | grep openfold
# Out:
# jurgjn/openfold   v2.2.0    6a0ee3eae374   8 minutes ago   23.7GB

# %%
docker push jurgjn/openfold:$OPENFOLD_VERSION
# Out:
# The push refers to repository [docker.io/jurgjn/openfold]
#
# caaf4964: Preparing
# bf18a086: Preparing
# c4bf8f9b: Preparing
# b1679203: Preparing
# 226b26d7: Preparing
# 82961d1c: Preparing
# f09c8e91: Preparing
# bf18a086: Preparing
# 78a6a351: Preparing
# cb3623d5: Preparing
# 457a315d: Preparing
# 4418d589: Preparing
# aa8ad722: Preparing
# 7575d475: Preparing
# 243f29a7: Preparing
# 77ab7383: Preparing
# 883f1a4f: Preparing
# 75a70a2f: Preparing
# e08aaa60: Preparing
# 903c2cc4: Preparing
# 7aeafbbf: Preparing
# bf43a888: Preparing
# 1df4adac: Preparing
# 0ebbe843: Preparing
# ff4e91d7: Preparing
# b659c9ab: Preparing
# d9dd29d6: Preparing
# v2.2.0: digest: sha256:1b024f44e25303473f6e2671d682fdd0e1677a05870dbded2b61d19518b07059 size: 6400

# %%
# Cleanup:
# docker system prune --all
# rm -rf ./openfold
