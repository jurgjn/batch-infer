# %%
cd openfold3
git merge-base main euler
cd -
# Out:
# 3cfe4830e4d9f29ce01ba522801a485a94998368
# /Users/jjaenes/26.02_batch-infer/software/openfold3

# %%
OF3_TAG='3cfe483-euler1'

# %%
cd openfold3
# https://github.com/aqlaboratory/openfold-3/blob/main/docker/DOCKER.md#production-images
time docker buildx build --platform=linux/amd64 --progress plain \
    -f docker/Dockerfile \
    --build-arg BUILD_MODE=lock \
    --build-arg CUDA_BASE_IMAGE_TAG=12.1.1-cudnn8-devel-ubuntu22.04 \
    --target test \
    -t jurgjn/openfold3:$OF3_TAG .
cd -
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 5.67kB done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/nvidia/cuda:12.1.1-cudnn8-devel-ubuntu22.04
# #2 ...
#
# #3 [auth] nvidia/cuda:pull token for registry-1.docker.io
# #3 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/nvidia/cuda:12.1.1-cudnn8-devel-ubuntu22.04
# #2 DONE 0.9s
#
# #4 [internal] load .dockerignore
# #4 transferring context: 273B done
# #4 DONE 0.0s
#
# #5 [builder  1/13] FROM docker.io/nvidia/cuda:12.1.1-cudnn8-devel-ubuntu22.04@sha256:21196d81f56b48dbee70494d5f10322e1a77cc47ffe202a3bf68eab81533c20f
# #5 DONE 0.0s
#
# #6 [internal] load build context
# #6 transferring context: 40.56kB 0.0s done
# #6 DONE 0.0s
#
# #7 [builder 12/13] WORKDIR /opt/openfold3
# #7 CACHED
#
# ...

# %%
docker image ls

# %%
docker push jurgjn/openfold3:$OF3_TAG
# Out:
# The push refers to repository [docker.io/jurgjn/openfold3]
#
# dfe03e11: Preparing
# 3b6ff38d: Preparing
# b5f4504d: Preparing
# bf18a086: Preparing
# 078e737a: Preparing
# a867d7af: Preparing
# 8a1359f9: Preparing
# 5dd4e9b6: Preparing
# fb0e6d90: Preparing
# 7d578a3f: Preparing
# 883f1a4f: Preparing
# 75a70a2f: Preparing
# e08aaa60: Preparing
# 903c2cc4: Preparing
# 7aeafbbf: Preparing
# bf43a888: Preparing
# 1df4adac: Preparing
# 0ebbe843: Preparing
# ff4e91d7: Preparing
# b659c9ab: Preparing
# d9dd29d6: Preparing
# 3cfe483-euler1: digest: sha256:90a846a7adf6b65eec75a318f5912e34a88fcc907cc8c23a2ffc4ad757873e45 size: 5157
