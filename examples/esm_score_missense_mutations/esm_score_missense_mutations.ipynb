# %%
# !cp _raw/CBS432.mitochondrial_genome.tidy.pep.fa input-fasta/CBS432.mitochondrial_genome.tidy.pep.fasta
# !cp _raw/CBS432.nuclear_genome.tidy.pep.fa input-fasta/CBS432.nuclear_genome.tidy.pep.fasta
# !cp _raw/CBS7001.asm03.HP0.mitochondrial_genome.tidy.pep.fa input-fasta/CBS7001.asm03.HP0.mitochondrial_genome.tidy.pep.fasta
# !cp _raw/CBS7001.nuclear_genome.tidy.pep.fa input-fasta/CBS7001.nuclear_genome.tidy.pep.fasta
# !cp _raw/CL450.mitochondrial_genome.tidy.pep.fa input-fasta/CL450.mitochondrial_genome.tidy.pep.fasta
# !cp _raw/CL450.nuclear_genome.tidy.pep.fa input-fasta/CL450.nuclear_genome.tidy.pep.fasta
# !cp _raw/CR85.mitochondrial_genome.tidy.pep.fa input-fasta/CR85.mitochondrial_genome.tidy.pep.fasta
# !cp _raw/CR85.nuclear_genome.tidy.pep.fa input-fasta/CR85.nuclear_genome.tidy.pep.fasta
# !cp _raw/H6.mitochondrial_genome.tidy.pep.fa input-fasta/H6.mitochondrial_genome.tidy.pep.fasta
# !cp _raw/H6.nuclear_genome.tidy.pep.fa input-fasta/H6.nuclear_genome.tidy.pep.fasta
# !cp _raw/IFO1815.asm02.HP0.mitochondrial_genome.tidy.pep.fa input-fasta/IFO1815.asm02.HP0.mitochondrial_genome.tidy.pep.fasta
# !cp _raw/IFO1815.nuclear_genome.tidy.pep.fa input-fasta/IFO1815.nuclear_genome.tidy.pep.fasta
# !cp _raw/NCYC3947.mitochondrial_genome.tidy.pep.fa input-fasta/NCYC3947.mitochondrial_genome.tidy.pep.fasta
# !cp _raw/NCYC3947.nuclear_genome.tidy.pep.fa input-fasta/NCYC3947.nuclear_genome.tidy.pep.fasta
# !cp _raw/YPS138.mitochondrial_genome.tidy.pep.fa input-fasta/YPS138.mitochondrial_genome.tidy.pep.fasta
# !cp _raw/YPS138.nuclear_genome.tidy.pep.fa input-fasta/YPS138.nuclear_genome.tidy.pep.fasta

# %%
# Pull image from Docker Hub
#!batch-infer singularity_pull ./ | sbatch
# Run data-only & GPU tests
# !batch-infer esm_score_missense_mutations ./ --dry-run | sbatch
# Out:
# /bin/bash: line 1: sbatch: command not found
# cat: write error: Broken pipe

# %%
# !squeue --format="%.18i %.12P %.128j %.8T %.16M %.16l %40R" | column -t --table-right 1,5,6 | grep esm_score

# %%
# !rm -rf .snakemake
# !rm -rf .snakemake-eu
# !rm -rf output-csv
