# %%
cd ~/batch-infer
./batch-infer openfold_test results/openfold_test | sbatch
# Out:
# Submitted batch job 38211468

# %%
my_squeue | grep openfold
# Out:
# 38207873  gpuhe.4h     openfold_test:                                                RUNNING        0:29     4:00:00  eu-g6-040
# 38207862  normal.120h  batch-infer:openfold_test=results-openfold_test               RUNNING        2:48  7-00:00:00  eu-g9-016-4
