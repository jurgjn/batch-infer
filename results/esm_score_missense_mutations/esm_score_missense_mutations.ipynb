# %%
# Pull image from Docker Hub
#!batch-infer singularity_pull ./ | sbatch
# Run data-only & GPU tests
# !batch-infer esm_score_missense_mutations ./ | sbatch
# Out:
# Submitted batch job 55694047

# %%
# !squeue --format="%.18i %.12P %.128j %.8T %.16M %.16l %40R" | column -t --table-right 1,5,6 | grep esm_score
# Out:
# 55597895  normal.120h  batch-infer:esm_score_missense_mutations=esm_score_missense_mutations                  PENDING        0:00  7-00:00:00  (Priority)

# %%
# !rm -rf .snakemake
# !rm -rf .snakemake-eu
# !rm -rf output-csv
