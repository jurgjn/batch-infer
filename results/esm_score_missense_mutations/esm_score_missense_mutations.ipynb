# %%
# Pull image from Docker Hub
#!batch-infer singularity_pull ./ | sbatch
# Run data-only & GPU tests
# !batch-infer esm_score_missense_mutations ./ | sbatch
# Out:
# Submitted batch job 55595197

# %%
# !squeue --format="%.18i %.12P %.128j %.8T %.16M %.16l %40R" | column -t --table-right 1,5,6 | grep esm_score
# Out:
# 55595254  gpu.24h      run_esm_score_missense_mutations:id=example                                            RUNNING        0:34  1-00:00:00  eu-lo-g3-048
# 55595197  normal.120h  batch-infer:esm_score_missense_mutations=esm_score_missense_mutations                  RUNNING        1:06  7-00:00:00  eu-a2p-530
