# %%
# Adapted from: https://github.com/PaddlePaddle/PaddleHelix/tree/dev/apps/protein_folding/helixfold3
module load stack/2024-04 gcc/8.5.0 cuda/12.1.1
module list
# Out:
# Many modules are hidden in this stack. Use "module --show_hidden spider SOFTWARE" if you are not able to find the required software
#
# Currently Loaded Modules:
#   1) eth_proxy   2) stack/2024-04   3) gcc/8.5.0   4) cuda/12.1.1

# %%
pwd
ls -l
rm -rf PaddleHelix
mamba env remove -n helixfold -y
# Out:
# /cluster/project/beltrao/jjaenes/22.05.30_alphafold_on_euler/openfold/software
# total 628
# -rw-r--r--  1 jjaenes biol-imsb-beltrao 313778 Sep  3 11:21 helixfold3-setup.ipynb
# drwxr-sr-x 16 jjaenes biol-imsb-beltrao   4096 Aug 22 11:36 openfold
# -rw-r--r--  1 jjaenes biol-imsb-beltrao 313206 Aug 22 11:36 openfold-setup.ipynb

# %%
git clone https://github.com/PaddlePaddle/PaddleHelix.git
cd PaddleHelix/apps/protein_folding/helixfold3
pwd
ls -l
# Out:
# Cloning into 'PaddleHelix'...
# remote: Enumerating objects: 8028, done.
# remote: Counting objects: 100% (1078/1078), done.
# remote: Compressing objects: 100% (455/455), done.
# remote: Total 8028 (delta 716), reused 848 (delta 608), pack-reused 6950 (from 1)
# Receiving objects: 100% (8028/8028), 134.72 MiB | 17.52 MiB/s, done.
# Resolving deltas: 100% (4016/4016), done.
# Updating files: 100% (1052/1052), done.
# bash: cd: apps/protein_folding/helixfold3: No such file or directory
# /cluster/project/beltrao/jjaenes/22.05.30_alphafold_on_euler/openfold/software
# total 572
# -rw-r--r--  1 jjaenes biol-imsb-beltrao 251659 Sep  3 11:22 helixfold3-setup.ipynb
# drwxr-sr-x 16 jjaenes biol-imsb-beltrao   4096 Aug 22 11:36 openfold
# -rw-r--r--  1 jjaenes biol-imsb-beltrao 313206 Aug 22 11:36 openfold-setup.ipynb
# drwxr-sr-x 12 jjaenes biol-imsb-beltrao   4096 Sep  3 11:22 PaddleHelix

# %%
mamba create -n helixfold -c conda-forge python=3.9 -y
mamba install -y -c bioconda aria2 hmmer==3.3.2 kalign2==2.04 hhsuite==3.3.0 -n helixfold
mamba install -y -c conda-forge openbabel -n helixfold
# Out:
# Looking for: ['python=3.9']
#
# warning  libmamba Cache file "/cluster/project/beltrao/jjaenes/software/miniconda3/pkgs/cache/497deca9.json" was modified by another program
# warning  libmamba Cache file "/cluster/project/beltrao/jjaenes/software/miniconda3/pkgs/cache/09cdf8bf.json" was modified by another program
# warning  libmamba Cache file "/cluster/project/beltrao/jjaenes/software/miniconda3/pkgs/cache/ffeee55f.json" was modified by another program
# [+] 0.0s
# [+] 0.1s
# bioconda/linux-64 (check zst) ━━╸━━━━━━━━━━━━   0.0 B @  ??.?MB/s Checking  0.1sbioconda/linux-64 (check zst)                       Checked  0.1s
# warning  libmamba Cache file "/cluster/project/beltrao/jjaenes/software/miniconda3/pkgs/cache/2a957770.json" was modified by another program
# [+] 0.0s
# bioconda/noarch (check zst) ━╸━━━━━━━━━━━━━━━   0.0 B @  ??.?MB/s Checking  0.0sbioconda/noarch (check zst)                         Checked  0.1s
# ...

# %%
echo $CONDA_DEFAULT_ENV
conda activate helixfold
echo $CONDA_DEFAULT_ENV
# Out:
# helixfold
# (helixfold)
# (helixfold)
# helixfold
# (helixfold)

# %%
# install paddlepaddle
python3 -m pip install paddlepaddle-gpu==2.6.1.post120 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# or lower version: https://paddle-wheel.bj.bcebos.com/2.5.1/linux/linux-gpu-cuda11.7-cudnn8.4.1-mkl-gcc8.2-avx/paddlepaddle_gpu-2.5.1.post117-cp39-cp39-linux_x86_64.whl
# Out:
# (helixfold)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Looking in links: https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.8/796.8 MB 13.4 MB/s eta 0:00:0000:0100:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 98.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 219.5 MB/s eta 0:00:00
# ...
# (helixfold)
# (helixfold)

# %%
python3 -m pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.2/669.2 kB 19.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 137.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 174.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 118.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 552.7/552.7 kB 109.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 MB 165.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 132.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 54.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 kB 143.2 MB/s eta 0:00:00
# ...

# %%
chmod u+x scripts/download_all_data.sh
scripts/download_all_data.sh /cluster/work/beltrao/jjaenes/24.09.03_helixfold3/data
#scripts/download_all_data.sh /cluster/work/beltrao/jjaenes/24.09.03_helixfold3/data_reduced_dbs reduced_dbs
# Out:
# (helixfold)
# ...
#
# 09/03 11:34:54 [NOTICE] Downloading 1 item(s)
#  *** Download Progress Summary as of Tue Sep  3 11:35:55 2024 ***              m8s]mm0m
# ...
# [#2ed2d1 517MiB/1.2GiB(39%) CN:1 DL:11MiB ETA:1m7s]
# FILE: /cluster/work/beltrao/jjaenes/24.09.03_helixfold3/data/params/HelixFold3-params-240814.zip
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Tue Sep  3 11:36:55 2024 ***              s]mm
# ...
# [#2ed2d1 1.1GiB/1.2GiB(93%) CN:1 DL:10MiB ETA:8s]
# FILE: /cluster/work/beltrao/jjaenes/24.09.03_helixfold3/data/params/HelixFold3-params-240814.zip
# -------------------------------------------------------------------------------
#
# [#2ed2d1 1.2GiB/1.2GiB(99%) CN:1 DL:10MiB]0m]m
# 09/03 11:37:03 [NOTICE] Download complete: /cluster/work/beltrao/jjaenes/24.09.03_helixfold3/data/params/HelixFold3-params-240814.zip
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ...
